# %% [markdown]
# ## Smarts Strings
#
# search technique like regular expressions but for molecules in smile format

# %%
import torch

from rdkit import Chem
from rdkit.Chem.Draw import MolsToGridImage

smiles_list = ["CCCCC", "CCOCC", "CCNCC", "CCSCC"]
mol_list = [Chem.MolFromSmiles(x) for x in smiles_list]

# %%
mol_list
# Out:
# [<rdkit.Chem.rdchem.Mol at 0x7f7c803173a0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f7c80148880>,
#  <rdkit.Chem.rdchem.Mol at 0x7f7cb0d8f1c0>,
#  <rdkit.Chem.rdchem.Mol at 0x7f7c92be8fa0>]

# %%
MolsToGridImage(mol_list)

# %% [markdown]
# ## Using SMARTS search

# %%
query = Chem.MolFromSmarts("CCC")
match_list = [mol.GetSubstructMatch(query) for mol in mol_list]

# %%
MolsToGridImage(mols=mol_list, molsPerRow=4, highlightAtomLists=match_list)

# %%
query = Chem.MolFromSmarts("C*C")
match_list = [mol.GetSubstructMatch(query) for mol in mol_list]
MolsToGridImage(mols=mol_list, molsPerRow=4, highlightAtomLists=match_list)

# %%
query = Chem.MolFromSmarts("C[C,N,O]C")
match_list = [mol.GetSubstructMatch(query) for mol in mol_list]
MolsToGridImage(mols=mol_list, molsPerRow=4, highlightAtomLists=match_list)
